# %%
import pandas as pd

# %%
house_data=pd.read_csv("rent.csv")
house_data
# Out:
#                   Price    Pid  \
# 0        400,000 / year  H1190
# 1     14,000,000 / year  G7398
# 2        200,000 / year  H5843
# 3        800,000 / year  H1194
# 4        300,000 / year  H5842
# ...                 ...    ...
# 9848     400,000 / year  F1443
# 9849            800,000  F1442
# 9850   1,000,000 / year  F1441
# 9851          1,500,000  F1433
# 9852          4,000,000  F1430
#
#                                           Property_name  \
# 0     1 bedroom mini flat Flat / Apartment for rent ...
# 1     3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2     1 bedroom mini flat Flat / Apartment for rent ...
# 3     2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4     1 bedroom mini flat Flat / Apartment for rent ...
# ...                                                 ...
# 9848  1 bedroom mini flat Flat / Apartment for rent ...
# 9849  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850  2 bedroom Flat / Apartment for rent Adekunle Y...
# ...

# %%
house_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9853 entries, 0 to 9852
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          9853 non-null   object
#  1   Pid            9853 non-null   object
#  2   Property_name  9853 non-null   object
#  3   Address        9853 non-null   object
# dtypes: object(4)
# memory usage: 308.0+ KB

# %%
house_data.describe()
# Out:
#             Price    Pid                                      Property_name  \
# count        9853   9853                                               9853
# unique        388   9850                                               4762
# top     1,000,000  G0258  3 bedroom Flat / Apartment for rent Lekki Phas...
# freq          289      2                                                103
#
#                        Address
# count                     9853
# unique                    5945
# top     Akoka Akoka Yaba Lagos
# freq                       122

# %%
house_data[["Property_name"]]
# Out:
#                                           Property_name
# 0     1 bedroom mini flat Flat / Apartment for rent ...
# 1     3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2     1 bedroom mini flat Flat / Apartment for rent ...
# 3     2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4     1 bedroom mini flat Flat / Apartment for rent ...
# ...                                                 ...
# 9848  1 bedroom mini flat Flat / Apartment for rent ...
# 9849  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850  2 bedroom Flat / Apartment for rent Adekunle Y...
# 9851  3 bedroom Duplex for rent Off Chief Echegile S...
# 9852  8 bedroom Duplex for rent babs Animashuam Bode...
#
# [9853 rows x 1 columns]

# %%
house_data.duplicated().sum()
# Out:
# 3

# %%
house_data[house_data.duplicated()]
# Out:
#             Price    Pid                                      Property_name  \
# 3274    1,000,000  G4171  3 bedroom Flat / Apartment for rent harmony es...
# 4405  1,200 / sqf  G6707  Commercial Property for rent Oba Akran Ikeja L...
# 6957    1,200,000  G0258  2 bedroom Flat / Apartment for rent Allen Aven...
#
#                                               Address
# 3274       harmony estate Ifako Gbagada Gbagada Lagos
# 4405        Close to mouka foam Oba Akran Ikeja Lagos
# 6957  Off Majekodunmi street Allen Avenue Ikeja Lagos

# %%
house_data=house_data.drop_duplicates()
house_data
# Out:
#                   Price    Pid  \
# 0        400,000 / year  H1190
# 1     14,000,000 / year  G7398
# 2        200,000 / year  H5843
# 3        800,000 / year  H1194
# 4        300,000 / year  H5842
# ...                 ...    ...
# 9848     400,000 / year  F1443
# 9849            800,000  F1442
# 9850   1,000,000 / year  F1441
# 9851          1,500,000  F1433
# 9852          4,000,000  F1430
#
#                                           Property_name  \
# 0     1 bedroom mini flat Flat / Apartment for rent ...
# 1     3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2     1 bedroom mini flat Flat / Apartment for rent ...
# 3     2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4     1 bedroom mini flat Flat / Apartment for rent ...
# ...                                                 ...
# 9848  1 bedroom mini flat Flat / Apartment for rent ...
# 9849  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850  2 bedroom Flat / Apartment for rent Adekunle Y...
# ...

# %%
house_data=house_data.drop(columns=['Pid'])
house_data
# Out:
#                   Price                                      Property_name  \
# 0        400,000 / year  1 bedroom mini flat Flat / Apartment for rent ...
# 1     14,000,000 / year  3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2        200,000 / year  1 bedroom mini flat Flat / Apartment for rent ...
# 3        800,000 / year  2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4        300,000 / year  1 bedroom mini flat Flat / Apartment for rent ...
# ...                 ...                                                ...
# 9848     400,000 / year  1 bedroom mini flat Flat / Apartment for rent ...
# 9849            800,000  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850   1,000,000 / year  2 bedroom Flat / Apartment for rent Adekunle Y...
# 9851          1,500,000  3 bedroom Duplex for rent Off Chief Echegile S...
# 9852          4,000,000  8 bedroom Duplex for rent babs Animashuam Bode...
#
#                                                 Address
# ...

# %%
house_data['Price']=house_data['Price'].str.replace(r'\D','',regex=True)
house_data['Price']=pd.to_numeric(house_data['Price'],errors='coerce')
house_data
# Out:
#          Price                                      Property_name  \
# 0       400000  1 bedroom mini flat Flat / Apartment for rent ...
# 1     14000000  3 bedroom Flat / Apartment for rent Gerrard Ge...
# 2       200000  1 bedroom mini flat Flat / Apartment for rent ...
# 3       800000  2 bedroom Flat / Apartment for rent Iju Ishaga...
# 4       300000  1 bedroom mini flat Flat / Apartment for rent ...
# ...        ...                                                ...
# 9848    400000  1 bedroom mini flat Flat / Apartment for rent ...
# 9849    800000  3 bedroom Flat / Apartment for rent Onike Yaba...
# 9850   1000000  2 bedroom Flat / Apartment for rent Adekunle Y...
# 9851   1500000  3 bedroom Duplex for rent Off Chief Echegile S...
# 9852   4000000  8 bedroom Duplex for rent babs Animashuam Bode...
#
#                                                 Address
# 0                        Fidiso Estate Abijo Ajah Lagos
# 1               Gerrard Gerrard Gerard Road Ikoyi Lagos
# ...

# %%
# Function to extract bedroom number
def extract_bedrooms(text):
    if pd.isna(text):
        return None
    match = re.search(r'(\d+)\s*bedroom', text.lower())
    return int(match.group(1)) if match else None

# Create new column
house_data['Bedroom'] = house_data['Property_name'].apply(extract_bedrooms)
house_data
# Preview result
#print(df[['Property_name', 'Bedroom']].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 9
#       6     return int(match.group(1)) if match else None
#       8 # Create new column
# ----> 9 house_data['Bedroom'] = house_data['Property_name'].apply(extract_bedrooms)
#      10 house_data
#
# File ~\anaconda\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
# ...

# %%
https://scores24.live/en/tennis/m-15-04-2026-blockx-alexander-shelton-ben

# %%
When NOT to transform:
1.Target is already fairly symmetric
2.You’re using tree models (Random Forest, XGBoost)
→ they handle skew better
3.You care about absolute error in original units and interpretability
 Best practice workflow:
.Train without transformation
.Train with log transformation
Compare:
from sklearn.metrics import mean_absolute_error

mae_original = mean_absolute_error(y_test, preds_original)
mae_log = mean_absolute_error(y_test, final_preds)

print(mae_original, mae_log)
